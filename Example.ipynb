# %%
from pedalpy import teamzwatt, wattbikehub

# %% [markdown]
# # TeamZwatt

# %%
filename = 'tests/fixtures/teamzwatt1.txt'
rdf_tz = teamzwatt.load(filename, normalize=False)

# %%
rdf_tz.plot.polar()

# %% [markdown]
# # Wattbike Hub

# %%
wbclient = wattbikehub.WattbikeHubClient(user_id='u-1756bbba7e2a350')

# %%
rdf_wb = wbclient.get_activity('2yBuOvd92C')

# %%
rdf_wb.plot.polar()
