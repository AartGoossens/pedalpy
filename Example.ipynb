# %%
from pedalpy import teamzwatt

# %%
fname = 'tests/fixtures/teamzwatt1.txt'
rdf = teamzwatt.load(fname, normalize=False)

# %%
rdf.plot.polar()
